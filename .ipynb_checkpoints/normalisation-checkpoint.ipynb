# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
df.sample(5)
# Out:
#      Class label  Alcohol  Malic acid
# 81             2    12.72        1.81
# 29             1    14.02        1.68
# 87             2    11.65        1.67
# 130            3    12.86        1.35
# 5              1    14.20        1.76

# %%
df.describe()
# Out:
#        Class label     Alcohol  Malic acid
# count   178.000000  178.000000  178.000000
# mean      1.938202   13.000618    2.336348
# std       0.775035    0.811827    1.117146
# min       1.000000   11.030000    0.740000
# 25%       1.000000   12.362500    1.602500
# 50%       2.000000   13.050000    1.865000
# 75%       3.000000   13.677500    3.082500
# max       3.000000   14.830000    5.800000

# %%
df.shape
# Out:
# (178, 3)

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop('Class label', axis = 1), df['Class label'], test_size = 0.3, random_state= 0)

# %%
x_train.shape, x_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled, x_train
# Out:
# (array([[0.72043011, 0.20378151],
#         [0.31989247, 0.08403361],
#         [0.60215054, 0.71218487],
#         [0.57258065, 0.56302521],
#         [0.76075269, 0.1302521 ],
#         [0.48924731, 0.5       ],
#         [0.75537634, 0.67857143],
#         [0.61021505, 0.17436975],
#         [0.54301075, 0.62394958],
#         [0.39784946, 0.07352941],
#         [0.33870968, 0.1092437 ],
#         [0.46774194, 0.53361345],
#         [0.5188172 , 0.53781513],
#         [0.70967742, 0.07563025],
#         [0.57258065, 0.30882353],
#         [0.36021505, 0.0105042 ],
#         [0.38709677, 0.13235294],
#         [0.20967742, 0.25840336],
#         [0.59408602, 0.64915966],
#         [0.82526882, 0.26680672],
#         [0.15591398, 0.09663866],
#         [0.52688172, 0.16386555],
#         [0.46774194, 0.31512605],
#         [0.65860215, 0.16386555],
#         [0.1155914 , 0.5987395 ],
#         [0.27956989, 0.26680672],
#         [0.21236559, 0.12184874],
#         [0.65053763, 0.59033613],
#         [0.31451613, 0.44957983],
#         [0.54301075, 0.17647059],
#         [0.57526882, 0.90336134],
#         [0.28225806, 0.09243697],
#         [0.30645161, 0.11764706],
#         [0.37365591, 0.74369748],
#         [0.22580645, 0.71848739],
#         [0.3172043 , 0.06302521],
#         [0.78225806, 0.17647059],
#         [0.82526882, 0.23739496],
#         [0.44086022, 0.01890756],
#         [1.        , 0.17647059],
#         [0.32795699, 0.80462185],
#         [0.48924731, 0.14915966],
#         [0.72580645, 0.7289916 ],
#         [0.81451613, 0.15546218],
#         [0.69892473, 0.19327731],
#         [0.34946237, 0.0210084 ],
#         [0.75      , 0.18067227],
#         [0.28225806, 0.25      ],
#         [0.53763441, 0.00210084],
#         [0.89784946, 0.22268908],
#         [0.57526882, 0.35714286],
#         [0.45430108, 0.18067227],
#         [0.90322581, 0.20588235],
#         [0.62096774, 0.0105042 ],
#         [0.16935484, 0.20798319],
#         [0.21774194, 0.        ],
#         [0.49193548, 0.09663866],
#         [0.7311828 , 0.17647059],
#         [0.40322581, 0.97058824],
#         [0.55913978, 0.21218487],
#         [0.90053763, 0.20588235],
#         [0.86021505, 0.17226891],
#         [0.26075269, 0.1302521 ],
#         [0.59139785, 0.50630252],
#         [0.90053763, 0.56722689],
#         [0.83064516, 0.12394958],
#         [0.26075269, 0.53361345],
#         [0.35215054, 0.32773109],
#         [0.65860215, 0.19327731],
#         [0.60752688, 0.22689076],
#         [0.63978495, 0.6197479 ],
#         [0.72043011, 1.        ],
#         [0.36021505, 0.06722689],
#         [0.58333333, 0.18697479],
#         [0.11290323, 0.31722689],
#         [0.69623656, 0.85294118],
#         [0.76612903, 0.21008403],
#         [0.37365591, 0.3487395 ],
#         [0.47849462, 0.29831933],
#         [0.41666667, 0.08403361],
#         [0.75268817, 0.14285714],
#         [0.5483871 , 0.12815126],
#         [0.44892473, 0.55882353],
#         [0.73655914, 0.21218487],
#         [0.48655914, 0.43487395],
#         [0.36021505, 0.15546218],
#         [0.66666667, 0.19117647],
#         [0.76344086, 0.21218487],
#         [0.28225806, 0.10504202],
#         [0.68548387, 0.16176471],
#         [0.55107527, 0.63235294],
#         [0.20430108, 0.2605042 ],
#         [0.38172043, 0.44957983],
#         [0.71236559, 0.19747899],
#         [0.66935484, 0.4789916 ],
#         [0.66397849, 0.46848739],
#         [0.49462366, 0.78151261],
#         [0.80376344, 0.16596639],
#         [0.33870968, 0.4789916 ],
#         [0.28225806, 0.05042017],
#         [0.44892473, 0.62605042],
#         [0.        , 0.1302521 ],
#         [0.6155914 , 0.49369748],
#         [0.83333333, 0.67436975],
#         [0.66129032, 0.16176471],
#         [0.21774194, 0.42016807],
#         [0.54301075, 0.24369748],
#         [0.45430108, 0.19327731],
#         [0.4811828 , 0.5210084 ],
#         [0.63709677, 0.77941176],
#         [0.85752688, 0.6512605 ],
#         [0.72311828, 0.11344538],
#         [0.51075269, 0.40336134],
#         [0.16397849, 0.24579832],
#         [0.33870968, 0.1512605 ],
#         [0.16666667, 0.16386555],
#         [0.60483871, 0.15756303],
#         [0.51075269, 0.61134454],
#         [0.76075269, 0.09663866],
#         [0.21236559, 0.17436975],
#         [0.36021505, 0.05882353],
#         [0.37365591, 0.1512605 ],
#         [0.77150538, 0.16596639],
#         [0.84139785, 0.34033613]]),
#       Alcohol  Malic acid
#  22     13.71        1.86
#  108    12.22        1.29
#  175    13.27        4.28
#  145    13.16        3.57
#  71     13.86        1.51
#  ..       ...         ...
#  103    11.82        1.72
#  67     12.37        1.17
#  117    12.42        1.61
#  47     13.90        1.68
#  172    14.16        2.51
#
#  [124 rows x 2 columns])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns = x_test.columns)

# %%
np.round(x_train.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(x_train_scaled.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count     54.0        54.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.1        -0.0
# 25%        0.4         0.1
# 50%        0.5         0.2
# 75%        0.7         0.4
# max        1.0         1.0

# %%
y_train.shape, x_test_scaled.shape
# Out:
# ((124,), (54, 2))

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (12,5))

ax1.scatter(x_train['Alcohol'], x_train['Malic acid'], c=y_train)
ax1.set_title("Before scaling")

ax2.scatter(x_train_scaled['Alcohol'], x_train_scaled['Malic acid'],c = y_train)
ax2.set_title('After scaling')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_axes.py:4725, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4724 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4725     colors = mcolors.to_rgba_array(c)
#    4726 except (TypeError, ValueError) as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\colors.py:514, in to_rgba_array(c, alpha)
#     513 else:
# --> 514     rgba = np.array([to_rgba(cc) for cc in c])
#     516 if alpha is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\colors.py:514, in <listcomp>(.0)
#     513 else:
# --> 514     rgba = np.array([to_rgba(cc) for cc in c])
#     516 if alpha is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\colors.py:316, in to_rgba(c, alpha)
#     315 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 316     rgba = _to_rgba_no_colorcycle(c, alpha)
#     317     try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\colors.py:400, in _to_rgba_no_colorcycle(c, alpha)
#     399 if not np.iterable(c):
# --> 400     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     401 if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: np.float64(1.0)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 6
#       3 ax1.scatter(x_train['Alcohol'], x_train['Malic acid'], c=y_train)
#       4 ax1.set_title("Before scaling")
# ----> 6 ax2.scatter(x_train_scaled['Alcohol'], x_train_scaled['Malic acid'],c = y_train)
#       7 ax2.set_title('After scaling')
#       9 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_axes.py:4918, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4915 if edgecolors is None:
#    4916     orig_edgecolor = kwargs.get('edgecolor', None)
#    4917 c, colors, edgecolors = \
# -> 4918     self._parse_scatter_color_args(
#    4919         c, edgecolors, kwargs, x.size,
#    4920         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4922 if plotnonfinite and colors is None:
#    4923     c = np.ma.masked_invalid(c)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_axes.py:4731, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4729 else:
#    4730     if not valid_shape:
# -> 4731         raise invalid_shape_exception(c.size, xsize) from err
#    4732     # Both the mapping *and* the RGBA conversion failed: pretty
#    4733     # severe failure => one may appreciate a verbose feedback.
#    4734     raise ValueError(
#    4735         f"'c' argument must be a color, a sequence of colors, "
#    4736         f"or a sequence of numbers, not {c!r}") from err
#
# ValueError: 'c' argument has 124 elements, which is inconsistent with 'x' and 'y' with size 54.
